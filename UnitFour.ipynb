# %%
import os
if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
from thinkdsp import*
import matplotlib.pyplot as plt
import numpy as np

# %%
signal=UncorrelatedGaussianNoise()
wave=signal.make_wave(duration=4,framerate=11025)
wave.plot()

# %%
spectrum=wave.make_spectrum()
spectrum.plot_power()

# %%
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pinknoisesignal=PinkNoise()
wavepink=pinknoisesignal.make_wave(duration=4,framerate=1000)
wavepink.plot()

# %%
spectrumpink=wavepink.make_spectrum()
spectrumpink.plot_power()

# %%
brosigNoise=BrownianNoise()
wavebro=brosigNoise.make_wave(duration=4,framerate=11025)
wavebro.plot()

# %%
brospectrum=wavebro.make_spectrum()
brospectrum.plot_power()
