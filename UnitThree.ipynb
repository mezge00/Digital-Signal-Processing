# %%
import os

# %%
import numpy as np
import matplotlib.pyplot as plt
from thinkdsp import*

# %%
signal=Chirp(start=220,end=440)
wave=signal.make_wave(duration=3)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
segment=wave.segment(duration=0.5)
segment.plot()

# %%
spectrum=wave.make_spectrum()
spectrum.plot(high=700)

# %%
signexpo=ExpoChirp(start=440,end=880)
waveexpo=signexpo.make_wave(duration=3)
waveexpo.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spectrumex=waveexpo.make_spectrum()
spectrumex.plot()

# %%
spect=segment.make_spectrogram(seg_length=512)
spect.plot(high=700)
